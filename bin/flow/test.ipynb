# %%
# %run set_data

test_set_output()
# Out:
# fcs_file: (43745, 32) [  8.53953200e+06   1.67419050e+07   3.01200000e+03]
# subset_fcs_file: (3, 32) [  1.89358100e+06   4.27779800e+06   9.93000000e+02]

# %%
# %run get_data
meta = fcsparser.parse("./subset_Well_C03.fcs", meta_data_only=True, reformat_meta=True)
meta
# Out:
# OrderedDict([('__header__',
#               {'FCS format': 'FCS3.0',
#                'analysis end': 0,
#                'analysis start': 0,
#                'data end': 11493,
#                'data start': 11110,
#                'text end': 11109,
#                'text start': 58}),
#              (u'$FIL', u'screen-934-cell-plate-1-well-C3.fcs'),
#              (u'$OP', u'Admin'),
#              (u'$SMNO', u'A01'),
#              (u'$DATATYPE', u'F'),
#              (u'$MODE', u'L'),
#              (u'$BYTEORD', u'4,3,2,1'),
#              (u'$NEXTDATA', 0),
#              (u'$PAR', 32),
#              (u'$TOT', 3),
#              (u'$DATE', u'11-MAR-2017'),
#              (u'$CYT', u'NovoCyte'),
#              (u'$SPILLOVER',
# ...
